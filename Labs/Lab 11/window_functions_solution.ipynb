# %% [markdown]
# ## Lab 11: Window Functions - grouping, but better!

# %% [markdown]
# Let's start by reviewing something we already know how to do - grouping based on some value set and then calculating things like the average or mean.
#
# We learnt how to do this using group_by() in lab 10 (before our data viz work!) - let's revise quickly.

# %%
import pandas as pd

# %%
# let's play with our old toy dataset for now
data = pd.DataFrame(
    data=[
        ['312', 'A1', 0.12, 'LEFT'],
        ['312', 'A2', 0.37, 'LEFT'],
        ['312', 'C2', 0.68, 'LEFT'],
        ['313', 'A1', 0.07, 'RIGHT'],
        ['313', 'B1', 0.08, 'RIGHT'],
        ['314', 'A2', 0.29, 'LEFT'],
        ['314', 'B1', 0.14, 'RIGHT'],
        ['314', 'C2', 0.73, 'RIGHT'],
        ['711', 'A1', 4.01, 'RIGHT'],
        ['712', 'A2', 3.29, 'LEFT'],
        ['713', 'B1', 5.74, 'LEFT'],
        ['714', 'B2', 3.32, 'RIGHT'],
    ],
    columns=['subject_id', 'condition_id', 'response_time', 'response'],
)
data
# Out:
#    subject_id condition_id  response_time response
# 0         312           A1           0.12     LEFT
# 1         312           A2           0.37     LEFT
# 2         312           C2           0.68     LEFT
# 3         313           A1           0.07    RIGHT
# 4         313           B1           0.08    RIGHT
# 5         314           A2           0.29     LEFT
# 6         314           B1           0.14    RIGHT
# 7         314           C2           0.73    RIGHT
# 8         711           A1           4.01    RIGHT
# 9         712           A2           3.29     LEFT
# 10        713           B1           5.74     LEFT
# 11        714           B2           3.32    RIGHT

# %%
data.groupby('condition_id')['response_time'].mean()
# Out:
# condition_id
# A1    1.400000
# A2    1.316667
# B1    1.986667
# B2    3.320000
# C2    0.705000
# Name: response_time, dtype: float64

# %%
data.groupby('subject_id')['response_time'].max()
# Out:
# subject_id
# 312    0.68
# 313    0.08
# 314    0.73
# 711    4.01
# 712    3.29
# 713    5.74
# 714    3.32
# Name: response_time, dtype: float64

# %% [markdown]
# What happens to the output - how does the size and shape change? What if we don't want our output to be a different shape or size?
#
# Or what if we want to group by something that isn't a categorical variable? What if we want to aggregate across a particualr time window? Or number of rows in a sliding fashion?
#
# E.g. what if we wanted to calculate the sum of every 5 rows at a time?
#
# Of course, we could do this with a for loop, but what about a more efficient approach (for our big health datasets!)? Time for "windows"!

# %% [markdown]
# ## Rolling Windows

# %% [markdown]
# Imagine you are a public health researcher with a dataset which spans many months and years and tracks some metrics of health across different groups or regions (sound familiar? most of your project datasets will likely look a bit like this).
#
# Now imagine you want to calculate some values of these metrics as they change over time. How can we do that?
#
# For example, let's say if your data is about the number of COVID-19 infections recorded in a  clinic. Any day there were positive cases the clinic logged them, if there were no cases then nothing was logged. You want to aggregate over different period of time, maybe over different windows of time to understand the average infection rates in a more dynamic way to grasp the disease dynmaics themselves.
#
# Let's build a toy version of that dataset and see can we figure out how to do that using "window" functions.

# %%
times = ['2021-01-01', '2021-01-03', '2021-01-04', '2021-01-05', '2021-01-29'] # let's set up some dates

s = pd.Series(range(5), index=pd.DatetimeIndex(times)) # and add an integer to each date that will represent our "recorded positive cases". 
s
# Out:
# 2021-01-01    0
# 2021-01-03    1
# 2021-01-04    2
# 2021-01-05    3
# 2021-01-29    4
# dtype: int64

# %% [markdown]
# Okay, let's say we want to start summing over some number of these rows to build a more "big picture" view of these numbers. Remember the rolling weekly infection rates from 2020?
#
# Jump here for a quick look: https://www.nyc.gov/site/doh/covid/covid-19-data.page#daily
#
# Let's try and get some of those kinds of numbers...
#
#
# The rolling() function will let us do just that by specifying a window that will sum the number of rows specified as our "window".
# Let's say we want to start simple, summing up a rolling addition every two days...

# %%
# Window with 2 observations
s.rolling(window=2).sum()
# Out:
# 2021-01-01    NaN
# 2021-01-03    1.0
# 2021-01-04    3.0
# 2021-01-05    5.0
# 2021-01-29    7.0
# dtype: float64

# %% [markdown]
# What do we notice?
#
# What happened with the shape of our dataframe? How is this different to something like group_by()?
# What about the first row, what happened there?
#
# But is this actually summing over a certain number of days? Look more carefully.
# Our days are evenly separated, some have gaps and some skip many days so we aren't actually getting a "two days rolling sum" like we hoped.
#
# Let's get more specific with our window function - it is really good at handling date items and understands units of time...

# %%
# Window with 2 days worth of observations
s.rolling(window='2D').sum()
# Out:
# 2021-01-01    0.0
# 2021-01-03    1.0
# 2021-01-04    3.0
# 2021-01-05    5.0
# 2021-01-29    4.0
# dtype: float64

# %% [markdown]
# Note that the unit of time here is days, it cannot be months as months have different numbers of days, if you tried something like "1M" you would get a  window error (try it and see what the error message is!)

# %%
s.rolling(window='1M').sum() # this will throw an error - examine it as part of improving your debugging!
# Out:
# C:\Users\sa4422\AppData\Local\Temp\ipykernel_39324\3550118969.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   s.rolling(window='1M').sum() # this will throw an error - examine it as part of improving your debugging!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s.rolling(window='1M').sum()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:12580, in NDFrame.rolling(self, window, min_periods, center, win_type, on, axis, closed, step, method)
#   12566 if win_type is not None:
#   12567     return Window(
#   12568         self,
#   12569         window=window,
#    (...)
#   12577         method=method,
#   12578     )
# > 12580 return Rolling(
#   12581     self,
#   12582     window=window,
#   12583     min_periods=min_periods,
#   12584     center=center,
#   12585     win_type=win_type,
#   12586     on=on,
#   12587     axis=axis,
#   12588     closed=closed,
#   12589     step=step,
#   12590     method=method,
#   12591 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:170, in BaseWindow.__init__(self, obj, window, min_periods, center, win_type, axis, on, closed, step, method, selection)
#     164     raise ValueError(
#     165         f"invalid on specified as {self.on}, "
#     166         "must be a column (of DataFrame), an Index or None"
#     167     )
#     169 self._selection = selection
# --> 170 self._validate()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:1899, in Rolling._validate(self)
#    1896     except TypeError:
#    1897         # if not a datetime dtype, eg for empty dataframes
#    1898         unit = "ns"
# -> 1899     self._win_freq_i8 = Timedelta(freq.nanos).as_unit(unit)._value
#    1901 # min_periods must be an integer
#    1902 if self.min_periods is None:
#
# File offsets.pyx:756, in pandas._libs.tslibs.offsets.BaseOffset.nanos.__get__()
#
# ValueError: <MonthEnd> is a non-fixed frequency

# %% [markdown]
# If you want to center the calculation around the current row then set center = True, spot the difference in these outputs to understand the difference.

# %%
s #these are the start value
# Out:
# 2021-01-01    0
# 2021-01-03    1
# 2021-01-04    2
# 2021-01-05    3
# 2021-01-29    4
# dtype: int64

# %%
s.rolling(window=3).sum()
# Out:
# 2021-01-01    NaN
# 2021-01-03    NaN
# 2021-01-04    3.0
# 2021-01-05    6.0
# 2021-01-29    9.0
# dtype: float64

# %%
s.rolling(window=3, center = True).sum()
# Out:
# 2021-01-01    NaN
# 2021-01-03    3.0
# 2021-01-04    6.0
# 2021-01-05    9.0
# 2021-01-29    NaN
# dtype: float64

# %% [markdown]
# ## Expanding windows

# %% [markdown]
# Okay - what if we want to watch positive cases accumulating over time - with each new row being added to the count? Again we could write a for loop - but that's rarely the best option!
#
# For this, we have the expanding() function which is used for cumulative or expanding window calculations. Unlike rolling(), which applies operations over a fixed-size window, expanding() grows the window size as it moves through the data. It starts at the first element and includes all prior elements up to the current one.

# %%
s # remember what we have already...
# Out:
# 2021-01-01    0
# 2021-01-03    1
# 2021-01-04    2
# 2021-01-05    3
# 2021-01-29    4
# dtype: int64

# %%
s.expanding(min_periods=1).sum()
# Out:
# 2021-01-01     0.0
# 2021-01-03     1.0
# 2021-01-04     3.0
# 2021-01-05     6.0
# 2021-01-29    10.0
# dtype: float64

# %%
s.expanding(min_periods=1).mean()
# Out:
# 2021-01-01    0.0
# 2021-01-03    0.5
# 2021-01-04    1.0
# 2021-01-05    1.5
# 2021-01-29    2.0
# dtype: float64

# %% [markdown]
# Note - these expanding calculations are a special case of rolling statistics. We could achieve an equivalent output with the following rolling() call...

# %%
s.rolling(window=len(s), min_periods=1).mean()
# Out:
# 2021-01-01    0.0
# 2021-01-03    0.5
# 2021-01-04    1.0
# 2021-01-05    1.5
# 2021-01-29    2.0
# dtype: float64

# %% [markdown]
# Why does this happen what is rolling() capturing with each step to achieve this?

# %% [markdown]
# ## Shifting rows

# %% [markdown]
# The .shift() function is used to shift the values of a column or index by a specified number of periods, either forward or backward. It's useful for creating lagged or lead features, comparing data points across different time steps (also good for time series analysis...)

# %% [markdown]
# Basic use case - you can use .shift() to calculate differences between current and past values.

# %%
data = {'values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
df
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
# Shifting values down by 1 period (default)
df['shifted_down'] = df['values'].shift(1)
df
# Out:
#    values  shifted_down
# 0      10           NaN
# 1      20          10.0
# 2      30          20.0
# 3      40          30.0
# 4      50          40.0

# %%
# Shifting values up by 1 period
df['shifted_up'] = df['values'].shift(-1)
df
# Out:
#    values  shifted_down  shifted_up
# 0      10           NaN        20.0
# 1      20          10.0        30.0
# 2      30          20.0        40.0
# 3      40          30.0        50.0
# 4      50          40.0         NaN

# %%
# Create a new column for the difference between the current and previous row
df['diff'] = df['values'] - df['values'].shift(1)
df
# Out:
#    values  shifted_down  shifted_up  diff
# 0      10           NaN        20.0   NaN
# 1      20          10.0        30.0  10.0
# 2      30          20.0        40.0  10.0
# 3      40          30.0        50.0  10.0
# 4      50          40.0         NaN  10.0

# %% [markdown]
# ## Exercise/Challenge: Back to our neural data
#
# #For each patcher, compute the average number of days they waited between experiments
#
# Here is how to proceed
# 1. Use a window function to compute the number of days that elapse between experiment (i.e., the distance between `date`), for each `patcher`. Add that as a new column, `'days from prev'`
# 2. Compute the average `'days from prev'` per patcher
#
# With your new awesome vectorization skills, it should only take two lines! (though you may have to lay around first to get here!

# %%
# Set some Pandas options: maximum number of rows/columns it's going to display
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('experiment_data.csv', parse_dates=['date']) # load in the data

# %%
df.head()
# Out:
#          OP patcher       date  slice  cell_ch       cell_ID day treatment  \
# 0  OP211209   Verji 2024-03-13     S2        8     21d10S2c8  D1      Ctrl
# 1  OP221024   Verji 2024-06-16     S3        4     22o24S3c4  D1      Ctrl
# 2  OP230810   Verji 2024-05-14     S2        5     23810S2c5  D1       TTX
# 3  OP230209   Verji 2024-04-27  S2_D2        3  23209S2_D2c3  D2    high K
# 4  OP240321   Verji 2024-04-11     S2        4     24321S2c4  D1      Ctrl
#
#    hrs_incubation repatch  hrs_after_OP         Rs         Rin  \
# 0             0.0      no     13.298889  14.470281  166.878916
# 1             0.0      no     23.964167  11.521243  137.820797
# 2             0.0      no      7.043056  10.120637   67.739416
# 3            25.0      no     21.848333   7.745503   43.009610
# 4             0.0      no     11.530278   7.632941   32.884808
#
#    resting_potential  max_spikes  Rheobase  AP_heigth         TH   max_depol  \
# 0         -67.962646          34      50.0  83.190918 -36.132812  302.124023
# 1         -71.789551          41      50.0  93.322754 -42.968750  465.820312
# 2         -70.629883          47     100.0  91.973877 -37.817383  415.771484
# 3         -68.371582          31     500.0  67.163086 -29.284668  212.036133
# 4         -52.453613          21     200.0  84.008789 -36.785889  403.442383
#
#     max_repol  membra_time_constant_tau  capacitance comments   rheo_ramp  \
# 0  -72.631836                     20.75   152.623120      NaN         NaN
# 1  -83.740234                     14.85   124.324170       17         NaN
# 2 -107.666016                     13.00   228.654858       10  402.013400
# 3  -61.645508                     11.05   215.784505       30  672.202407
# 4  -71.899414                     14.80   695.791105        8         NaN
#
#    AP_halfwidth  Rheobse_ramp  Unnamed: 27  rheos_ramp comment      \
# 0      0.966102           NaN          NaN         NaN     NaN NaN
# 1      0.959995           NaN          NaN         NaN     NaN NaN
# 2      0.760052           NaN          NaN         NaN     NaN NaN
# 3      0.958735           NaN          NaN         NaN     NaN NaN
# 4      1.063838    324.520817          NaN         NaN     NaN NaN
#
#   high K concentration  RMP_from_char tissue_source      area  patient_age
# 0                15 mM     -59.101382     Bielefeld  temporal         27.0
# 1                 8 mM     -62.265689     Bielefeld  temporal         42.0
# 2                 8 mM     -61.329228         Mitte  temporal         63.0
# 3                 8 mM     -62.577472     Bielefeld  temporal         63.0
# 4                 8 mM     -63.149769     Bielefeld  temporal         31.0

# %%
df['patcher'].unique() # we have two none NAN values here ....
# Out:
# array(['Verji', 'Rosie', nan], dtype=object)

# %%
df['days from prev'] = df['date'] - df.sort_values('date').groupby('patcher')['date'].shift()
df
# Out:
#            OP patcher       date  slice  cell_ch              cell_ID day  \
# 0    OP211209   Verji 2024-03-13     S2        8            21d10S2c8  D1
# 1    OP221024   Verji 2024-06-16     S3        4            22o24S3c4  D1
# 2    OP230810   Verji 2024-05-14     S2        5            23810S2c5  D1
# 3    OP230209   Verji 2024-04-27  S2_D2        3         23209S2_D2c3  D2
# 4    OP240321   Verji 2024-04-11     S2        4            24321S2c4  D1
# 5    OP220127   Rosie 2024-07-22  S2_D2        5         22129S2_D2c5  D2
# 6    OP221024   Verji 2024-06-14  S2_D2        4            22o24S2c5  D2
# 7    OP221027   Verji 2024-02-01  S2_D2        2            22o27S2c2  D2
# 8    OP240215   Verji 2024-02-10     S1        4            24215S1c4  D1
# 9    OP230808   Verji 2024-04-04     S5        4            23808S5c4  D1
# 10   OP220127   Rosie 2024-07-20  S1_D2        8         22129S1_D2c8  D2
# 11   OP230426   Verji 2024-01-16     S3        6            23426S3c6  D1
# 12   OP230810   Verji 2024-05-12     S1        7            23810S1c7  D1
# 13   OP240321   Verji 2024-04-12     S2        8            24321S2c8  D1
# 14   OP220322   Verji 2024-06-28  S1_D2        6         22322S1_D2c6  D2
# 15   OP220120   Rosie 2024-03-02  S2_D2        7         22122S2_D2c7  D2
# 16   OP230209   Verji 2024-04-25  S3_D2        3            23209S3c3  D2
# 17   OP220518   Verji 2024-07-10  S2_D2        5         22519S2_D2c5  D2
# 18   OP230314   Verji 2024-07-23     S3        7            23314S3c7  D1
# 19   OP220217   Verji 2024-06-05  S2_D2        3         22218S2_D2c3  D2
# 20   OP230808   Verji 2024-04-02     S3        8            23808S3c8  D1
# 21   OP220914   Verji 2024-07-06  S2_D2        6         22915S2_D2c6  D2
# 22   OP220111   Rosie 2024-06-11  S1_D2        4            22111S1c4  D2
# 23   OP230109   Verji 2024-02-29  S2_D2        2          2311S2_D2c2  D2
# 24   OP240201   Verji 2024-03-04     S1        6            24201S1c6  D1
# 25   OP210615   Rosie 2024-03-08     S4        2     2021_06_15_0S4c2  D1
# 26   OP230808   Verji 2024-04-02     S4        4            23808S4c4  D1
# 27   OP210615   Rosie 2024-03-04     S2        2     2021_06_15_0S2c2  D1
# 28   OP210323   Rosie 2024-06-02  S6_D2        2  2021_03_25_0S6_D2c1  D2
# 29   OP230109   Verji 2024-02-26     S2        8             2311S2c8  D1
# 30   OP210323   Rosie 2024-05-19     S4        7     2021_03_24_0S4c7  D1
# 31   OP220217   Verji 2024-05-30     S3        4            22217S3c4  D1
# 32   OP230314   Verji 2024-07-22     S3        5            23314S3c5  D1
# 33   OP230314   Verji 2024-07-20  S3_D2        4            23314S3c3  D2
# 34   OP230420   Verji 2024-01-05     S2        8            23420S2c8  D1
# 35   OP220127   Rosie 2024-06-27  S1_D2        4            22128S1c2  D2
# 36   OP220426   Verji 2024-01-21  S2_D2        5         22427S2_D2c5  D2
# 37   OP230808   Verji 2024-03-29  S2_D2        1            23808S2c2  D2
# 38   OP210615   Rosie 2024-03-06     S4        2     2021_06_15_0S4c1  D1
# 39   OP230523   Verji 2024-03-11     S3        2            23523S3c2  D1
# 40   OP220127   Rosie 2024-01-23     S2        1            22127S2c1  D1
# 41   OP220127   Rosie 2024-01-30  S3_D2        3            22127S3c3  D2
# 42   OP220426   Verji 2024-01-17     S2        6            22427S2c6  D1
# 43   OP231123   Verji 2024-03-27  S2_D2        7         23n23S2_D2c7  D2
# 44   OP201029   Rosie 2024-03-17     S1        7            20o29S1c7  D1
# 45   OP210323   Rosie 2024-05-04     S3        6     2021_03_24_0S3c6  D1
# 46   OP231123   Verji 2024-03-25     S2        5            23n23S2c5  D1
# 47   OP211123   Rosie 2024-01-05  S1_D2        5            21n23S1c4  D2
# 48   OP231130   Verji 2024-01-21     S1        5            23n30S1c5  D1
# 49   OP230817   Verji 2024-05-08     S3        8            23817S3c8  D1
# 50   OP240201   Verji 2024-03-04     S1        1            24201S1c1  D1
# 51   OP221027   Verji 2024-01-31     S2        2            22o27S2c2  D1
# 52   OP220426   Verji 2024-01-20     S3        5            22427S3c5  D1
# 53   OP211123   Rosie 2024-01-12  S2_D2        7         21n24S2_D2c7  D2
# 54   OP221027   Verji 2024-02-05  S2_D2        7         22o27S2_D2c7  D2
# 55   OP221027   Verji 2024-01-30  S2_D2        1            22o27S2c1  D2
# 56   OP220111   Rosie 2024-06-14  S5_D2        3         22112S5_D2c3  D2
# 57   OP220602     NaN 2024-07-19  S3_D2        8         22602S3_D2c8  D2
# 58   OP221024   Verji 2024-06-10  S1_D2        4            22o24S1c3  D2
# 59   OP220308   Verji 2024-06-21     S1        8            22308S1c8  D1
# 60   OP220811   Verji 2024-06-09  S2_D2        5         22811S2_D2c5  D2
# 61   OP220623   Verji 2024-01-07     S2        3            22623S2c3  D1
# 62   OP240417   Verji 2024-02-19  S3_D2        6            24417S3c6  D1
# 63   OP240503   Verji 2024-04-28     S2        5            24503S2c5  D1
# 64   OP220111   Rosie 2024-06-10     S1        4            22111S1c4  D1
# 65   OP230808   Verji 2024-03-28     S1        3            23808S1c3  D1
# 66   OP211209   Verji 2024-03-21  S1_D2        5         21d10S1_D2c5  D2
# 67   OP201029   Rosie 2024-03-20     S2        2            20o29S2c2  D1
# 68   OP230209   Verji 2024-04-21     S1        3            23209S1c3  D1
# 69   OP210323   Rosie 2024-04-12     S1        2     2021_03_24_0S1c2  D1
# 70   OP201027   Rosie 2024-03-26     S1        2            20o27S1c2  D1
# 71   OP230209   Verji 2024-04-22     S2        5            23209S2c5  D1
# 72   OP201027   Rosie 2024-03-29     S1        7            20o27S1c7  D1
# 73   OP240221   Verji 2024-06-19     S1        4            24221S1c4  D1
# 74   OP230817   Verji 2024-05-09  S1_D2        7         23817S1_D2c7  D2
# 75   OP231130   Verji 2024-01-21     S1        1            23n30S1c1  D1
# 76   OP220602     NaN 2024-05-31     S3        1            22602S3c1  D1
# 77   OP220127   Rosie 2024-02-16  S4_D2        2         22127S4_D2c2  D2
# 78   OP240503   Verji 2024-04-30  S3_D2        8            24503S3c8  D2
# 79   OP211209   Verji 2024-03-14     S3        8            21d10S3c8  D1
# 80   OP230209   Verji 2024-04-24  S2_D2        7            23209S2c7  D2
# 81   OP240321   Verji 2024-04-20  S2_D2        2         24321S2_D2c2  D2
# 82   OP220322   Verji 2024-06-30  S2_D2        3         22322S2_D2c3  D2
# 83   OP220127   Rosie 2024-02-12  S2_D2        6         22127S2_D2c6  D2
# 84   OP220127   Rosie 2024-07-06     S3        2            22128S3c2  D1
# 85   OP220111   Rosie 2024-06-17  S1_D2        4         22112S1_D2c2  D2
# 86   OP230808   Verji 2024-04-08  S3_D2        2         23808S3_D2c2  D2
# 87   OP230109   Verji 2024-02-23     S2        1             2311S2c1  D1
# 88   OP240321   Verji 2024-04-08     S1        1            24321S1c1  D1
# 89   OP220228   Verji 2024-05-20  S2_D2        5            22228S2c6  D2
# 90   OP231109   Verji 2024-01-11     S1        2            23n09S1c2  D1
# 91   OP220217   Verji 2024-05-28  S2_D2        6            22217S2c6  D2
# 92   OP230523   Verji 2024-03-09     S1        2            23523S1c2  D1
# 93   OP211209   Verji 2024-03-24  S3_D2        2         21d10S3_D2c2  D2
# 94   OP231123   Verji 2024-03-27  S2_D2        5         23n23S2_D2c5  D2
# 95   OP220623   Verji 2024-01-09     S4        6            22623S4c6  D1
# 96   OP221020   Verji 2024-01-28  S6_D2        4         22o21S6_D2c4  D2
# 97   OP221020   Verji 2024-01-29  S6_D2        6         22o21S6_D2c6  D2
# 98   OP231130   Verji 2024-01-26  S2_D2        7         23n30S2_D2c7  D2
# 99   OP230808   Verji 2024-04-03     S4        5            23808S4c5  D1
# 100  OP220120   Rosie 2024-03-01  S2_D2        4         22122S2_D2c4  D2
# 101  OP211123   Rosie 2024-03-30     S2        4     2021_11_24_0S2c4  D1
# 102  OP211123   Rosie 2024-01-04     S1        4            21n23S1c4  D1
# 103  OP220217   Verji 2024-05-30  S3_D2        3            22217S3c3  D2
# 104  OP220623   Verji 2024-01-08     S3        6            22623S3c6  D1
# 105  OP240118   Verji 2024-07-31  S2_D2        3         24118S2_D2c3  D2
# 106  OP221024   Verji 2024-06-16  S1_D2        5         22o24S1_D2c5  D2
# 107  OP210323   Rosie 2024-05-10  S3_D2        5     2021_03_24_0S3c6  D2
# 108  OP221024   Verji 2024-06-16     S3        3            22o24S3c3  D1
# 109  OP221024   Verji 2024-06-10     S1        2            22o24S1c2  D1
# 110  OP211123   Rosie 2024-04-09  S3_D2        2  2021_11_25_0S3_D2c3  D2
# 111  OP221027   Verji 2024-02-04     S3        1            22o27S3c1  D1
# 112  OP240221   Verji 2024-06-20     S1        7            24221S1c7  D1
# 113  OP210323   Rosie 2024-04-20     S1        5     2021_03_24_0S1c5  D1
# 114  OP220127   Rosie 2024-07-11     S4        4            22128S4c4  D1
# 115  OP220914   Verji 2024-07-05  S2_D2        3            22915S2c4  D2
# 116  OP220127   Rosie 2024-01-18     S1        5            22127S1c5  D1
# 117  OP230314   Verji 2024-07-14     S2        2            23314S2c2  D1
# 118  OP230109   Verji 2024-03-02  S3_D2        2          2311S3_D2c2  D2
# 119  OP210615   Rosie 2024-03-08     S5        3     2021_06_16_0S5c1  D2
# 120  OP220518   Verji 2024-07-08     S4        1            22519S4c1  D1
# 121  OP220127   Rosie 2024-07-16  S4_D2        3            22128S4c4  D2
# 122  OP220127   Rosie 2024-07-18     S4        8            22128S4c8  D1
# 123  OP211123   Rosie 2024-04-01     S2        5     2021_11_24_0S2c5  D1
# 124  OP230808   Verji 2024-04-01     S3        4            23808S3c4  D1
# 125  OP220322   Verji 2024-06-26  S1_D2        1         22322S1_D2c1  D2
# 126  OP230109   Verji 2024-02-26  S2_D2        5             2311S2c7  D2
# 127  OP240321   Verji 2024-04-13     S4        6            24321S4c6  D1
# 128  OP230810   Verji 2024-05-12     S1        5            23810S1c5  D1
# 129  OP240417   Verji 2024-02-21  S1_D2        1         24417S1_D2c1  D2
# 130  OP220228   Verji 2024-05-20     S3        2            22228S3c2  D1
# 131  OP211123   Rosie 2024-01-11     S2        6            21n23S2c6  D1
# 132  OP221027   Verji 2024-01-29     S1        1            22o27S1c1  D1
# 133  OP220127   Rosie 2024-02-10  S1_D2        4         22127S1_D2c4  D2
# 134  OP220127   Rosie 2024-02-06  S3_D2        6            22127S3c6  D2
# 135  OP240503   Verji 2024-04-28  S2_D2        5            24503S2c5  D2
# 136  OP220602     NaN 2024-06-21  S3_D2        3            22602S3c6  D2
# 137  OP221024   Verji 2024-06-10     S1        3            22o24S1c3  D1
# 138  OP221024   Verji 2024-06-14  S2_D2        3            22o24S2c4  D2
# 139  OP210323   Rosie 2024-05-31     S6        2     2021_03_24_0S6c5  D1
# 140  OP211209   Verji 2024-03-20     S5        4            21d10S5c4  D1
# 141  OP230209   Verji 2024-04-27  S2_D2        8         23209S2_D2c8  D2
# 142  OP220602     NaN 2024-06-11     S3        6            22602S3c6  D1
# 143  OP220914   Verji 2024-07-05  S3_D2        1            22915S3c6  D2
# 144  OP230808   Verji 2024-04-03     S5        2            23808S5c2  D1
# 145  OP221020   Verji 2024-01-28  S5_D2        7         22o21S5_D2c7  D2
# 146  OP230426   Verji 2024-01-16     S3        4            23426S3c4  D1
# 147  OP220518   Verji 2024-07-07     S1        8            22519S1c8  D1
# 148  OP211123   Rosie 2024-01-07     S1        7            21n23S1c7  D1
# 149  OP220914   Verji 2024-07-03     S1        3            22915S1c3  D1
# 150  OP231130   Verji 2024-01-25  S2_D2        6         23n30S2_D2c6  D2
# 151  OP211209   Verji 2024-03-12     S1        5            21d10S1c5  D1
# 152  OP231109   Verji 2024-01-14     S2        8            23n09S2c8  D1
# 153  OP220217   Verji 2024-06-02     S3        8            22217S3c8  D1
# 154  OP230314   Verji 2024-07-19     S3        2            23314S3c2  D1
# 155  OP220127   Rosie 2024-01-27     S3        1            22127S3c1  D1
# 156  OP240411   Verji 2024-02-09  S1_D2        5         24411S1_D2c5  D2
# 157  OP240411   Verji 2024-02-07     S3        2            24411S3c2  D1
# 158  OP220228   Verji 2024-05-19     S1        7            22228S1c7  D1
# 159  OP220228   Verji 2024-05-18     S1        3            22228S1c3  D1
# 160  OP230109   Verji 2024-02-29  S1_D2        5          2311S1_D2c5  D2
# 161  OP220111   Rosie 2024-06-13     S1        7            22111S1c7  D1
# 162  OP230810   Verji 2024-05-15     S3        1            23810S3c1  D1
# 163  OP220120   Rosie 2024-02-25     S2        3            22121S2c3  D1
# 164  OP220127   Rosie 2024-07-29  S4_D2        7         22129S4_D2c7  D2
# 165  OP230314   Verji 2024-07-22     S3        6            23314S3c6  D1
# 166  OP230109   Verji 2024-02-24     S2        5             2311S2c5  D1
# 167  OP230314   Verji 2024-07-24  S3_D2        7            23314S3c7  D2
# 168  OP230808   Verji 2024-03-28     S1        6            23808S1c6  D1
# 169  OP221024   Verji 2024-06-10  S1_D2        3            22o24S1c2  D2
# 170  OP220217   Verji 2024-05-26     S1        6            22217S1c6  D1
# 171  OP221020   Verji 2024-01-28  S5_D2        2         22o21S5_D2c2  D2
# 172  OP240417   Verji 2024-02-20     S3        8            24417S3c8  D1
# 173  OP220217   Verji 2024-05-26     S2        2            22217S2c2  D1
# 174  OP220811   Verji 2024-06-09  S3_D2        8         22811S3_D2c8  D2
# 175  OP231123   Verji 2024-03-26  S2_D2        2         23n23S2_D2c2  D2
# 176  OP230810   Verji 2024-05-16     S3        5            23810S3c5  D1
# 177  OP210615   Rosie 2024-03-02     S1        2     2021_06_15_0S1c2  D1
# 178  OP240503   Verji 2024-05-01  S3_D2        3         24503S3_D2c3  D2
# 179  OP230314   Verji 2024-07-26  S4_D2        6         23314S4_D2c6  D2
# 180  OP220120   Rosie 2024-02-24     S2        1            22121S2c1  D1
# 181  OP240417   Verji 2024-02-13     S1        4            24417S1c4  D1
# 182  OP220518   Verji 2024-07-09     s6        6            22519s6c6  D1
# 183  OP210323   Rosie 2024-05-19     S4        6     2021_03_24_0S4c6  D1
# 184  OP230808   Verji 2024-04-06  S1_D2        2         23808S1_D2c2  D2
# 185  OP221027   Verji 2024-02-05  S3_D2        2            22o27S3c2  D2
# 186  OP240321   Verji 2024-04-13     S3        3            24321S3c3  D1
# 187  OP240411   Verji 2024-02-09  S2_D2        5            24411S2c5  D2
# 188  OP240417   Verji 2024-02-12  S1_D2        2            24417S1c2  D2
# 189  OP210323   Rosie 2024-06-02  S4_D2        1  2021_03_25_0S6_D2c1  D2
# 190  OP211123   Rosie 2024-04-04     S3        2     2021_11_24_0S3c2  D1
# 191  OP211209   Verji 2024-03-13     S2        6            21d10S2c6  D1
# 192  OP211209   Verji 2024-03-20  S5_D2        5            21d10S5c4  D2
# 193  OP240411   Verji 2024-02-06  S2_D2        1            24411S2c1  D2
# 194  OP240417   Verji 2024-02-15     S1        6            24417S1c6  D1
# 195  OP210323   Rosie 2024-05-16     S4        4     2021_03_24_0S4c4  D1
# 196  OP230209   Verji 2024-04-24     S3        2            23209S3c2  D1
# 197  OP220308   Verji 2024-06-22     S3        7            22308S3c7  D1
# 198  OP201029   Rosie 2024-03-18     S1        8            20o29S1c8  D1
# 199  OP240117   Verji 2024-07-31  S2_D2        2         24117S2_D2c2  D1
# 200  OP211123   Rosie 2024-04-03     S2        7     2021_11_24_0S2c7  D1
# 201  OP240321   Verji 2024-04-18  S1_D2        6         24321S1_D2c6  D2
# 202  OP230314   Verji 2024-07-16  S2_D2        2            23314S2c3  D2
# 203  OP240503   Verji 2024-04-30  S3_D2        6            24503S3c6  D2
# 204  OP230817   Verji 2024-05-10  S2_D2        5         23817S2_D2c5  D2
# 205  OP220602     NaN 2024-07-04  S1_D2        7         22602S1_D2c7  D2
# 206  OP220127   Rosie 2024-07-29  S4_D2        8         22129S4_D2c8  D2
# 207  OP220914   Verji 2024-07-04     S3        6            22915S3c6  D1
# 208  OP210323   Rosie 2024-05-24     S6        2     2021_03_24_0S5c1  D1
# 209  OP240503   Verji 2024-04-30     S3        6            24503S3c6  D1
# 210  OP240221   Verji 2024-06-20     S1        6            24221S1c6  D1
# 211  OP201029   Rosie 2024-03-22  S2_D2        2            20o29S2c2  D2
# 212  OP210323   Rosie 2024-04-19  S1_D2        8     2021_03_24_0S1c4  D2
# 213  OP220228   Verji 2024-05-20     S3        1            22228S3c1  D1
# 214  OP240117   Verji 2024-07-27     S2        7            24117S2c7  D1
# 215  OP220217   Verji 2024-05-27  S2_D2        2            22217S2c2  D2
# 216  OP230109   Verji 2024-02-25     S2        7             2311S2c7  D1
# 217  OP240417   Verji 2024-02-21  S2_D2        2            24417S2c2  D2
# 218  OP240507   Verji 2024-01-10  S2_D2        4            24507S2c5  D2
# 219  OP211209   Verji 2024-03-19     S5        2            21d10S5c2  D1
# 220  OP220228   Verji 2024-05-23     S3        6            22228S3c6  D1
# 221  OP220811   Verji 2024-06-07  S2_D2        1         22811S2_D2c1  D2
# 222  OP221020   Verji 2024-01-28  S5_D2        6         22o21S5_D2c6  D2
# 223  OP221024   Verji 2024-06-13     S2        4            22o24S2c4  D1
# 224  OP220217   Verji 2024-06-03  S1_D2        6         22218S1_D2c6  D2
# 225  OP230426   Verji 2024-01-16     S3        5            23426S3c5  D1
# 226  OP210323   Rosie 2024-04-26     S1        8     2021_03_24_0S1c8  D1
# 227  OP240221   Verji 2024-06-19     S1        3            24221S1c3  D1
# 228  OP240417   Verji 2024-02-15  S1_D2        6            24417S1c6  D2
# 229  OP230109   Verji 2024-02-28  S1_D2        3          2311S1_D2c3  D2
# 230  OP240201   Verji 2024-03-08  S2_D2        2         24201S2_D2c2  D2
# 231  OP220127   Rosie 2024-06-19     S1        1            22128S1c1  D1
# 232  OP220127   Rosie 2024-02-16  S2_D2        8         22127S2_D2c8  D2
# 233  OP210323   Rosie 2024-05-15     S4        2     2021_03_24_0S4c2  D1
# 234  OP220127   Rosie 2024-01-20     S1        7            22127S1c7  D1
# 235  OP220426   Verji 2024-01-18     S3        3            22427S3c3  D1
# 236  OP211123   Rosie 2024-04-07     S3        7     2021_11_24_0S3c7  D1
# 237  OP240417   Verji 2024-02-16     S3        2            24417S3c2  D1
# 238  OP231130   Verji 2024-01-25  S1_D2        4         23n30S1_D2c4  D2
# 239  OP220228   Verji 2024-05-20     S2        6            22228S2c6  D1
# 240  OP220322   Verji 2024-06-25     S3        6            22322S3c6  D1
# 241  OP210323   Rosie 2024-06-02  S1_D2        1  2021_03_25_0S1_D2c1  D2
# 242  OP240507   Verji 2024-01-11  S3_D2        6         24507S3_D2c6  D2
# 243  OP240215   Verji 2024-02-10     S1        3            24215S1c3  D1
# 244  OP240321   Verji 2024-04-12  S2_D2        8            24321S2c8  D2
# 245  OP220127   Rosie 2024-01-28     S3        2            22127S3c2  D1
# 246  OP221024   Verji 2024-06-16     S3        5            22o24S3c5  D1
# 247  OP220623   Verji 2024-01-07     S2        5            22623S2c5  D1
# 248  OP210615   Rosie 2024-03-03     S1        7     2021_06_15_0S1c7  D1
# 249  OP231130   Verji 2024-01-23     S2        8            23n30S2c8  D1
# 250  OP220811   Verji 2024-06-09  S3_D2        5         22811S3_D2c5  D2
# 251  OP211123   Rosie 2024-01-01     S1        1            21n23S1c1  D1
# 252  OP220308   Verji 2024-06-21     S1        7            22308S1c7  D1
# 253  OP221024   Verji 2024-06-16  S2_D2        6         22o24S2_D2c6  D2
# 254  OP230209   Verji 2024-04-26  S1_D2        5         23209S1_D2c5  D2
# 255  OP220217   Verji 2024-05-25  S1_D2        1            22217S1c1  D2
# 256  OP201027   Rosie 2024-03-29     S2        1            20o27S2c1  D1
# 257  OP240117   Verji 2024-07-30  S1_D2        2         24117S1_D2c2  D2
# 258  OP240117   Verji 2024-07-31  S2_D2        4         24117S2_D2c4  D1
# 259  OP240118   Verji 2024-07-31     S2        7            24118S2c7  D1
# 260  OP230420   Verji 2024-01-02     S1        6            23420S1c6  D1
# 261  OP220602     NaN 2024-05-18     S2        6            22602S2c6  D1
# 262  OP230109   Verji 2024-03-03  S3_D2        4          2311S3_D2c4  D2
# 263  OP230314   Verji 2024-07-25     S4        8            23314S4c8  D1
# 264  OP220217   Verji 2024-05-31     S3        6            22217S3c6  D1
# 265  OP240321   Verji 2024-04-09     S1        7            24321S1c7  D1
# 266  OP201029   Rosie 2024-03-18     S1        8            20o29S1c8  D1
# 267  OP220120   Rosie 2024-02-20     S1        1            22121S1c1  D1
# 268  OP221027   Verji 2024-02-02     S2        7            22o27S2c7  D1
# 269  OP230420   Verji 2024-01-02     S1        3            23420S1c3  D1
# 270  OP220127   Rosie 2024-02-06     S4        1            22127S4c1  D1
# 271  OP240411   Verji 2024-02-06     S2        1            24411S2c1  D1
# 272  OP240321   Verji 2024-04-17     S4        7            24321S4c7  D1
# 273  OP220322   Verji 2024-06-26  S3_D2        6            22322S3c7  D2
# 274  OP240503   Verji 2024-05-02  S3_D2        7            24503S3c7  D2
# 275  OP230420   Verji 2024-01-06  S2_D2        4            23420S2c4  D2
# 276  OP240411   Verji 2024-02-09  S3_D2        4         24411S3_D2c4  D2
# 277  OP220127   Rosie 2024-07-09     S4        2            22128S4c2  D1
# 278  OP210323   Rosie 2024-05-11  S3_D2        8     2021_03_24_0S3c8  D2
# 279  OP220602     NaN 2024-07-16  S3_D2        4         22602S3_D2c4  D2
# 280  OP230420   Verji 2024-01-01     S1        1            23420S1c1  D1
# 281  OP230109   Verji 2024-03-01  S2_D2        8          2311S2_D2c8  D2
# 282  OP230817   Verji 2024-05-08  S1_D2        3         23817S1_D2c3  D2
# 283  OP230109   Verji 2024-02-26     S3        3             2311S3c3  D1
# 284  OP240503   Verji 2024-04-28  S2_D2        3            24503S2c3  D2
# 285  OP240503   Verji 2024-04-29     S3        5            24503S3c5  D1
# 286  OP220127   Rosie 2024-07-01     S2        6            22128S2c6  D1
# 287  OP230808   Verji 2024-03-29     S2        7            23808S2c7  D1
# 288  OP230808   Verji 2024-04-06  S1_D2        7         23808S1_D2c7  D2
# 289  OP221024   Verji 2024-06-17  S3_D2        2         22o24S3_D2c2  D2
# 290  OP240201   Verji 2024-03-08  S2_D2        7         24201S2_D2c7  D2
# 291  OP230109   Verji 2024-02-24     S2        6             2311S2c6  D1
# 292  OP230420   Verji 2024-01-02  S1_D2        8            23420S1c8  D2
# 293  OP220308   Verji 2024-06-21     S1        5            22308S1c5  D1
# 294  OP240411   Verji 2024-02-08     S3        3            24411S3c3  D1
# 295  OP210615   Rosie 2024-03-12  S4_D2        2  2021_06_16_0S4_D1c3  D2
# 296  OP220127   Rosie 2024-01-31     S3        5            22127S3c5  D1
# 297  OP240321   Verji 2024-04-17  S1_D2        5         24321S1_D2c5  D2
# 298  OP240417   Verji 2024-02-16     S3        5            24417S3c5  D1
# 299  OP230426   Verji 2024-01-14     S1        8            23426S1c8  D1
# 300  OP230109   Verji 2024-03-02  S3_D2        1          2311S3_D2c1  D2
# 301  OP230817   Verji 2024-05-08     S3        6            23817S3c6  D1
# 302  OP220518   Verji 2024-07-08     S4        6            22519S4c6  D1
# 303  OP230810   Verji 2024-05-11     S1        4            23810S1c4  D1
# 304  OP230808   Verji 2024-04-08  S3_D2        4         23808S3_D2c4  D2
# 305  OP220518   Verji 2024-07-07     S1        6            22519S1c6  D1
# 306  OP220217   Verji 2024-06-03  S1_D2        8         22218S1_D2c8  D2
# 307  OP240503   Verji 2024-04-30     S3        8            24503S3c8  D1
# 308  OP211209   Verji 2024-03-15     S4        2            21d10S4c2  D1
# 309  OP220127   Rosie 2024-06-29     S1        7            22128S1c7  D1
# 310  OP230314   Verji 2024-07-14     S1        8            23314S1c8  D1
# 311  OP230523   Verji 2024-03-11     S3        8            23523S3c8  D1
# 312  OP210323   Rosie 2024-04-24  S1_D2        6     2021_03_24_0S1c6  D2
# 313  OP240201   Verji 2024-03-04     S1        3            24201S1c3  D1
# 314  OP220127   Rosie 2024-07-04     S2        8            22128S2c8  D1
# 315  OP221024   Verji 2024-06-14     S2        5            22o24S2c5  D1
# 316  OP220217   Verji 2024-06-01     S3        7            22217S3c7  D1
# 317  OP220602     NaN 2024-01-15     S1        4            22602S1c4  D1
# 318  OP210323   Rosie 2024-06-10  S5_D2        2  2021_03_25_0S4_D2c1  D2
# 319  OP210323   Rosie 2024-04-28     S3        2     2021_03_24_0S3c2  D1
# 320  OP220127   Rosie 2024-02-12  S2_D2        2         22127S2_D2c2  D2
# 321  OP240117   Verji 2024-07-30  S2_D2        1         24117S2_D2c1  D1
# 322  OP220127   Rosie 2024-01-25  S2_D2        5            22127S2c5  D2
# 323  OP240507   Verji 2024-01-10     S2        6            24507S2c6  D1
# 324  OP210323   Rosie 2024-04-12  S1_D2        4     2021_03_24_0S1c2  D2
# 325  OP220127   Rosie 2024-06-30     S2        1            22128S2c1  D1
# 326  OP240117   Verji 2024-07-31  S2_D2        3         24117S2_D2c3  D1
# 327  OP210323   Rosie 2024-05-18     S4        5     2021_03_24_0S4c5  D1
# 328  OP230420   Verji 2024-01-05  S2_D2        8            23420S2c7  D2
# 329  OP220127   Rosie 2024-07-26  S3_D2        7         22129S3_D2c7  D2
# 330  OP220322   Verji 2024-06-25     S2        6            22322S2c6  D1
# 331  OP221020   Verji 2024-01-28  S4_D2        4         22o21S4_D2c4  D2
# 332  OP220308   Verji 2024-06-20     S1        3            22308S1c3  D1
# 333  OP201029   Rosie 2024-03-24     S2        4            20o29S2c4  D1
# 334  OP220426   Verji 2024-01-21  S4_D2        2            22427S4c6  D2
# 335  OP220127   Rosie 2024-02-17  S4_D2        6         22127S4_D2c6  D2
# 336  OP230109   Verji 2024-02-27     S3        5             2311S3c5  D1
# 337  OP211209   Verji 2024-03-15     S4        4            21d10S4c4  D1
# 338  OP221020   Verji 2024-01-29  S6_D2        8         22o21S6_D2c8  D2
# 339  OP220127   Rosie 2024-01-23     S2        4            22127S2c4  D1
# 340  OP220127   Rosie 2024-01-17     S1        2            22127S1c2  D1
# 341  OP231123   Verji 2024-03-24     S1        4            23n23S1c4  D1
# 342  OP220127   Rosie 2024-07-22  S2_D2        7         22129S2_D2c7  D2
# 343  OP220322   Verji 2024-06-26  S1_D2        2         22322S1_D2c2  D2
# 344  OP211209   Verji 2024-03-19  S5_D2        1            21d10S5c1  D2
# 345  OP220322   Verji 2024-07-02  S2_D2        7            22322S2c8  D2
# 346  OP220127   Rosie 2024-06-21     S1        2            22128S1c2  D1
# 347  OP220120   Rosie 2024-07-31  S1_D2        2            22121S1c8  D2
# 348  OP231109   Verji 2024-01-14     S1        7            23n09S1c7  D1
# 349  OP240201   Verji 2024-03-04     S1        2            24201S1c2  D1
# 350  OP220217   Verji 2024-05-26     S1        2            22217S1c2  D1
# 351  OP220322   Verji 2024-06-25     S3        7            22322S3c7  D1
# 352  OP220127   Rosie 2024-07-04     S2        7            22128S2c7  D1
# 353  OP220308   Verji 2024-06-20     S1        4            22308S1c4  D1
# 354  OP210323   Rosie 2024-06-08  S4_D2        8  2021_03_25_0S4_D2c8  D2
# 355  OP211123   Rosie 2024-01-04     S1        2            21n23S1c2  D1
# 356  OP220120   Rosie 2024-02-27     S2        6            22121S2c6  D1
# 357  OP211123   Rosie 2024-01-09     S2        1            21n23S2c1  D1
# 358  OP230209   Verji 2024-04-27  S3_D2        7         23209S3_D2c7  D2
# 359  OP220228   Verji 2024-05-20  S3_D2        1            22228S3c1  D2
# 360  OP230314   Verji 2024-07-24     S4        5            23314S4c5  D1
# 361  OP211209   Verji 2024-03-20  S1_D2        3         21d10S1_D2c3  D2
# 362  OP221020   Verji 2024-01-28  S6_D2        2         22o21S6_D2c2  D2
# 363  OP211209   Verji 2024-03-15     S4        5            21d10S4c5  D1
# 364  OP230314   Verji 2024-07-24     S4        7            23314S4c7  D1
# 365  OP211209   Verji 2024-03-13     S3        7            21d10S3c7  D1
# 366  OP230209   Verji 2024-04-21     S2        2            23209S2c2  D1
# 367  OP221027   Verji 2024-01-30     S2        1            22o27S2c1  D1
# 368  OP220602     NaN 2024-03-26     S1        6            22602S1c6  D1
# 369  OP221027   Verji 2024-02-06  S3_D2        6         22o27S3_D2c6  D2
# 370  OP211209   Verji 2024-03-18     S5        1            21d10S5c1  D1
# 371  OP231123   Verji 2024-03-25     S1        8            23n23S1c8  D1
# 372  OP240411   Verji 2024-02-09  S2_D2        4            24411S2c4  D2
# 373  OP220127   Rosie 2024-07-02  S2_D2        6            22128S2c6  D2
# 374  OP240201   Verji 2024-03-06  S1_D2        2         24201S1_D2c2  D2
# 375  OP220127   Rosie 2024-01-29     S3        3            22127S3c3  D1
# 376  OP220127   Rosie 2024-01-30     S3        4            22127S3c4  D1
# 377  OP211209   Verji 2024-03-16     S4        6            21d10S4c6  D1
# 378  OP231123   Verji 2024-03-25     S2        4            23n23S2c4  D1
# 379  OP220426   Verji 2024-01-20     S4        5            22427S4c5  D1
# 380  OP230209   Verji 2024-04-25     S3        4            23209S3c4  D1
# 381  OP211209   Verji 2024-03-22  S2_D2        3         21d10S2_D2c3  D2
# 382  OP220623   Verji 2024-01-09     S4        1            22623S4c1  D1
# 383  OP220322   Verji 2024-07-01  S2_D2        4         22322S2_D2c4  D2
# 384  OP240507   Verji 2024-01-10     S3        2            24507S3c2  D1
# 385  OP220602     NaN 2024-07-04  S2_D2        7         22602S2_D2c7  D2
# 386  OP220127   Rosie 2024-06-27     S1        4            22128S1c4  D1
# 387  OP220322   Verji 2024-06-24     S1        7            22322S1c7  D1
# 388  OP221024   Verji 2024-06-10     S1        1            22o24S1c1  D1
# 389  OP230808   Verji 2024-04-02     S3        5            23808S3c5  D1
# 390  OP230109   Verji 2024-02-23  S2_D2        1             2311S2c1  D2
# 391  OP211123   Rosie 2024-04-03     S2        8     2021_11_24_0S2c8  D1
# 392  OP240503   Verji 2024-04-29  S3_D2        5            24503S3c5  D2
# 393  OP240117   Verji 2024-07-26     S1        7            24117S1c7  D1
# 394  OP220217   Verji 2024-05-24     S1        1            22217S1c1  D1
# 395  OP240507   Verji 2024-01-09     S2        4            24507S2c4  D1
# 396  OP230817   Verji 2024-05-02     S1        2            23817S1c2  D1
# 397  OP220914   Verji 2024-07-04     S1        4            22915S1c4  D1
# 398  OP230109   Verji 2024-02-22     S1        8             2311S1c8  D1
# 399  OP230808   Verji 2024-04-03     S5        1            23808S5c1  D1
# 400  OP221020   Verji 2024-01-27  S4_D2        2         22o21S4_D2c2  D2
# 401  OP210615   Rosie 2024-03-03     S1        4     2021_06_15_0S1c4  D1
# 402  OP201029   Rosie 2024-03-25     S2        7            20o29S2c7  D1
# 403  OP220322   Verji 2024-06-26  S1_D2        3         22322S1_D2c3  D2
# 404  OP240117   Verji 2024-07-26     S2        6            24117S2c6  D1
# 405  OP220127   Rosie 2024-01-31  S3_D2        5            22127S3c5  D2
# 406  OP240503   Verji 2024-04-28     S2        3            24503S2c3  D1
# 407  OP220602     NaN 2024-04-27     S2        3            22602S2c3  D1
# 408  OP220120   Rosie 2024-07-30     S1        8            22121S1c8  D1
# 409  OP220322   Verji 2024-07-03  S3_D2        3         22322S3_D2c3  D2
# 410  OP220120   Rosie 2024-03-02  S2_D2        5         22122S2_D2c5  D2
# 411  OP211209   Verji 2024-03-13     S3        5            21d10S3c5  D1
# 412  OP220127   Rosie 2024-01-31  S3_D2        4            22127S3c4  D2
# 413  OP240117   Verji 2024-07-30  S1_D2        8         24117S1_D2c8  D2
# 414  OP221027   Verji 2024-02-01     S2        3            22o27S2c3  D1
# 415  OP230523   Verji 2024-03-10     S2        7            23523S2c7  D1
# 416  OP240321   Verji 2024-04-13     S4        3            24321S4c3  D1
# 417  OP220111   Rosie 2024-06-16  S1_D2        8         22112S1_D2c8  D2
# 418  OP220127   Rosie 2024-07-06  S3_D2        3            22128S3c6  D2
# 419  OP230420   Verji 2024-01-02     S1        8            23420S1c8  D1
# 420  OP220228   Verji 2024-05-21     S3        3            22228S3c3  D1
# 421  OP230209   Verji 2024-04-21     S2        1            23209S2c1  D1
# 422  OP220228   Verji 2024-05-19     S2        5            22228S2c5  D1
# 423  OP231109   Verji 2024-01-14     S2        7            23n09S2c7  D1
# 424  OP220127   Rosie 2024-07-07     S3        7            22128S3c7  D1
# 425  OP231123   Verji 2024-03-25  S1_D2        8         23n23S1_D2c8  D2
# 426  OP220322   Verji 2024-06-24     S1        3            22322S1c3  D1
# 427  OP221024   Verji 2024-06-11     S2        1            22o24S2c1  D1
# 428  OP220602     NaN 2024-03-07  S1_D2        4            22602S1c5  D2
# 429  OP240503   Verji 2024-04-28     S2        6            24503S2c6  D1
# 430  OP220127   Rosie 2024-06-28  S1_D2        5            22128S1c4  D2
# 431  OP211123   Rosie 2024-01-10     S2        5            21n23S2c5  D1
# 432  OP230808   Verji 2024-04-06     S6        4            23808S6c4  D1
# 433  OP220217   Verji 2024-06-07  S2_D2        8         22218S2_D2c8  D2
# 434  OP230808   Verji 2024-03-30     S2        8            23808S2c8  D1
# 435  OP220811   Verji 2024-06-08  S2_D2        4         22811S2_D2c4  D2
# 436  OP211209   Verji 2024-03-18     S4        8            21d10S4c8  D1
# 437  OP221024   Verji 2024-06-14     S2        6            22o24S2c6  D1
# 438  OP230109   Verji 2024-02-24     S2        2             2311S2c2  D1
# 439  OP220120   Rosie 2024-02-28  S1_D2        5         22122S1_D2c5  D2
# 440  OP201029   Rosie 2024-03-19     S1        3            20o29S1c3  D1
# 441  OP240215   Verji 2024-02-11  S1_D2        1            24215S1c1  D2
# 442  OP220127   Rosie 2024-01-25     S2        5            22127S2c5  D1
# 443  OP240417   Verji 2024-02-16     S1        7            24417S1c7  D1
# 444  OP230420   Verji 2024-01-03  S2_D2        2            23420S2c2  D2
# 445  OP220322   Verji 2024-06-27  S1_D2        5         22322S1_D2c5  D2
# 446  OP220308   Verji 2024-06-21  S1_D2        7            22308S1c8  D2
# 447  OP231123   Verji 2024-03-24     S1        1            23n23S1c1  D1
# 448  OP230314   Verji 2024-07-18     S2        7            23314S2c7  D1
# 449  OP221027   Verji 2024-02-05     S3        3            22o27S3c3  D1
# 450  OP230109   Verji 2024-02-22     S1        2             2311S1c2  D1
# 451  OP231109   Verji 2024-01-14     S2        2            23n09S2c2  D1
# 452  OP240215   Verji 2024-02-11  S2_D2        2            24215S2c2  D2
# 453  OP210323   Rosie 2024-04-09     S1        1     2021_03_24_0S1c1  D1
# 454  OP221027   Verji 2024-02-02     S2        5            22o27S2c5  D1
# 455  OP220127   Rosie 2024-07-25  S2_D2        8         22129S2_D2c8  D2
# 456  OP240201   Verji 2024-03-05     S2        1            24201S2c1  D1
# 457  OP220518   Verji 2024-07-11  S3_D2        6         22519S3_D2c6  D2
# 458  OP210323   Rosie 2024-05-22     S5        2     2021_03_24_0S5c1  D1
# 459  OP240417   Verji 2024-02-18     S3        6            24417S3c6  D1
# 460  OP240321   Verji 2024-04-09     S1        8            24321S1c8  D1
# 461  OP240411   Verji 2024-02-06     S1        8            24411S1c8  D1
# 462  OP220518   Verji 2024-07-09     s6        2            22519s6c2  D1
# 463  OP240321   Verji 2024-04-13     S3        7            24321S3c7  D1
# 464  OP210323   Rosie 2024-05-29     S6        2     2021_03_24_0S6c3  D1
# 465  OP240201   Verji 2024-03-06  S1_D2        5         24201S1_D2c5  D2
# 466  OP230817   Verji 2024-05-11  S2_D2        7         23817S2_D2c7  D2
# 467  OP220111   Rosie 2024-06-15  S5_D2        6         22112S5_D2c6  D2
# 468  OP211209   Verji 2024-03-17     S4        7            21d10S4c7  D1
# 469  OP221027   Verji 2024-02-05     S3        2            22o27S3c2  D1
# 470  OP240201   Verji 2024-03-05     S1        8            24201S1c8  D1
# 471  OP220308   Verji 2024-06-23     S3        8            22308S3c8  D1
# 472  OP220811   Verji 2024-06-08  S2_D2        3         22811S2_D2c3  D2
# 473  OP211209   Verji 2024-03-23  S2_D2        8         21d10S2_D2c8  D2
# 474  OP220602     NaN 2024-06-22     S3        7            22602S3c7  D1
# 475  OP230109   Verji 2024-02-28  S3_D2        5             2311S3c7  D2
# 476  OP230810   Verji 2024-05-13     S2        3            23810S2c3  D1
# 477  OP211123   Rosie 2024-01-05     S1        5            21n23S1c5  D1
# 478  OP220228   Verji 2024-05-24  S3_D2        2         22228S3_D2c2  D2
# 479  OP210323   Rosie 2024-04-15     S1        4     2021_03_24_0S1c4  D1
# 480  OP240201   Verji 2024-03-07  S1_D2        7         24201S1_D2c7  D2
# 481  OP220518   Verji 2024-07-11  S3_D2        7         22519S3_D2c7  D2
# 482  OP230209   Verji 2024-04-26     S3        5            23209S3c5  D1
# 483  OP220127   Rosie 2024-01-25     S2        6            22127S2c6  D1
# 484  OP221024   Verji 2024-06-13     S2        2            22o24S2c2  D1
# 485  OP240117   Verji 2024-07-28     S2        8            24117S2c8  D1
# 486  OP220518   Verji 2024-07-13  S6_D2        3         22519S6_D2c3  D2
# 487  OP221027   Verji 2024-02-05     S3        7            22o27S3c7  D1
# 488  OP240221   Verji 2024-06-19  S1_D2        2            24221S1c3  D2
# 489  OP230808   Verji 2024-04-02     S3        6            23808S3c6  D1
# 490  OP231109   Verji 2024-01-12     S1        5            23n09S1c5  D1
# 491  OP240321   Verji 2024-04-20  S2_D2        3         24321S2_D2c3  D2
# 492  OP220111   Rosie 2024-06-15  S6_D2        4         22112S6_D2c4  D2
# 493  OP230109   Verji 2024-02-27     S3        7             2311S3c7  D1
# 494  OP230314   Verji 2024-07-24     S4        1            23314S4c1  D1
# 495  OP240117   Verji 2024-07-31  S2_D2        5         24117S2_D2c5  D1
# 496  OP220322   Verji 2024-06-30  S2_D2        2         22322S2_D2c2  D2
# 497  OP220602     NaN 2024-06-27  S3_D2        6            22602S3c7  D2
# 498  OP220518   Verji 2024-07-10  S6_D2        1            22519s6c7  D2
# 499  OP220228   Verji 2024-05-18     S1        2            22228S1c2  D1
# 500  OP220228   Verji 2024-05-23  S3_D2        5            22228S3c6  D2
# 501  OP201029   Rosie 2024-03-14     S1        2            20o29S1c2  D1
# 502  OP220518   Verji 2024-07-06     S1        1            22519S1c1  D1
# 503  OP220228   Verji 2024-05-24  S3_D2        6            22228S3c7  D2
# 504  OP240321   Verji 2024-04-19  S2_D2        1            24321S2c1  D2
# 505  OP220111   Rosie 2024-06-12  S1_D2        5            22111S1c5  D2
# 506  OP230808   Verji 2024-03-29     S2        2            23808S2c2  D1
# 507  OP220127   Rosie 2024-01-19     S1        6            22127S1c6  D1
# 508  OP220322   Verji 2024-06-25     S2        7            22322S2c7  D1
# 509  OP221027   Verji 2024-02-06  S3_D2        8         22o27S3_D2c8  D2
# 510  OP220127   Rosie 2024-07-06     S3        6            22128S3c6  D1
# 511  OP220602     NaN 2024-03-27     S1        8            22602S1c8  D1
# 512  OP220120   Rosie 2024-02-28  S1_D2        4         22122S1_D2c4  D2
# 513  OP201029   Rosie 2024-03-15     S1        5            20o29S1c5  D1
# 514  OP201027   Rosie 2024-03-27  S1_D2        2            20o27S1c2  D2
# 515  OP220623   Verji 2024-01-07     S3        4            22623S3c4  D1
# 516  OP230314   Verji 2024-07-15     S2        3            23314S2c3  D1
# 517  OP220217   Verji 2024-06-02  S1_D2        3         22218S1_D2c3  D2
# 518  OP220127   Rosie 2024-02-17  S4_D2        3         22127S4_D2c3  D2
# 519  OP230817   Verji 2024-05-04     S1        7            23817S1c7  D1
# 520  OP220623   Verji 2024-01-08     S3        7            22623S3c7  D1
# 521  OP220623   Verji 2024-01-07     S2        8            22623S2c8  D1
# 522  OP230817   Verji 2024-05-04     S2        2            23817S2c2  D1
# 523  OP230817   Verji 2024-05-05     S2        4            23817S2c4  D1
# 524  OP221020   Verji 2024-01-26  S4_D2        1         22o21S4_D2c1  D2
# 525  OP210323   Rosie 2024-06-04  S6_D2        2  2021_03_25_0S6_D2c3  D2
# 526  OP240117   Verji 2024-07-30  S1_D2        4         24117S1_D2c4  D2
# 527  OP210323   Rosie 2024-05-10     S3        8     2021_03_24_0S3c8  D1
# 528  OP220518   Verji 2024-07-09     s6        7            22519s6c7  D1
# 529  OP230314   Verji 2024-07-13     S1        2            23314S1c2  D1
# 530  OP230314   Verji 2024-07-20     S3        4            23314S3c4  D1
# 531  OP230817   Verji 2024-05-03     S1        4            23817S1c4  D1
# 532  OP240201   Verji 2024-03-08  S2_D2        8         24201S2_D2c8  D2
# 533  OP230420   Verji 2024-01-06  S2_D2        7         23420S2_D2c7  D2
# 534  OP230808   Verji 2024-04-01     S3        3            23808S3c3  D1
# 535  OP230314   Verji 2024-07-24     S4        4            23314S4c4  D1
# 536  OP210323   Rosie 2024-06-03  S6_D2        2  2021_03_25_0S6_D2c2  D2
# 537  OP230109   Verji 2024-03-01  S2_D2        7          2311S2_D2c7  D2
# 538  OP230420   Verji 2024-01-06  S2_D2        3            23420S2c6  D2
# 539  OP240411   Verji 2024-02-10  S3_D2        5            24411S3c5  D2
# 540  OP210615   Rosie 2024-03-12  S4_D2        4  2021_06_16_0S4_D1c2  D2
# 541  OP220127   Rosie 2024-06-30     S2        5            22128S2c5  D1
# 542  OP220228   Verji 2024-05-19  S1_D2        7            22228S1c7  D2
# 543  OP230420   Verji 2024-01-05     S2        7            23420S2c7  D1
# 544  OP220120   Rosie 2024-02-22     S1        2            22121S1c2  D1
# 545  OP220217   Verji 2024-05-28     S2        8            22217S2c8  D1
# 546  OP230810   Verji 2024-05-14     S2        4            23810S2c4  D1
# 547  OP220426   Verji 2024-01-18     S3        1            22427S3c1  D1
# 548  OP220228   Verji 2024-05-24  S3_D2        3         22228S3_D2c3  D2
# 549  OP230808   Verji 2024-03-29     S1        8            23808S1c8  D1
# 550  OP240417   Verji 2024-02-16     S2        1            24417S2c1  D1
# 551  OP211209   Verji 2024-03-24  S4_D2        8         21d11S4_D2c8  D2
# 552  OP231109   Verji 2024-01-13     S1        6            23n09S1c6  D1
# 553  OP220217   Verji 2024-05-29     S3        3            22217S3c3  D1
# 554  OP230314   Verji 2024-07-24     S3        8            23314S3c8  D1
# 555  OP220602     NaN 2024-06-11     S3        5            22602S3c5  D1
# 556  OP220127   Rosie 2024-01-28  S3_D2        2            22127S3c2  D2
# 557  OP240321   Verji 2024-04-13     S3        6            24321S3c6  D1
# 558  OP230523   Verji 2024-03-10     S1        5            23523S1c5  D1
# 559  OP221024   Verji 2024-06-10     S1        6            22o24S1c6  D1
# 560  OP210323   Rosie 2024-04-10  S1_D2        2     2021_03_24_0S1c1  D2
# 561  OP230109   Verji 2024-02-23  S1_D2        6             2311S1c8  D2
# 562  OP230209   Verji 2024-04-22  S2_D2        6            23209S2c6  D2
# 563  OP220602     NaN 2024-06-28  S1_D2        6         22602S1_D2c6  D2
# 564  OP231130   Verji 2024-01-23  S2_D2        1            23n30S2c8  D2
# 565  OP230314   Verji 2024-07-19     S3        3            23314S3c3  D1
# 566  OP231130   Verji 2024-01-24  S1_D2        2         23n30S1_D2c2  D2
# 567  OP230817   Verji 2024-05-10  S2_D2        4            23817S2c6  D2
# 568  OP220127   Rosie 2024-02-08     S4        3            22127S4c3  D1
# 569  OP230817   Verji 2024-05-10  S2_D2        1         23817S2_D2c1  D2
# 570  OP240321   Verji 2024-04-09     S1        4            24321S1c4  D1
# 571  OP220217   Verji 2024-05-28     S2        6            22217S2c6  D1
# 572  OP220127   Rosie 2024-02-09     S4        5            22127S4c5  D1
# 573  OP220914   Verji 2024-07-06  S2_D2        7         22915S2_D2c7  D2
# 574  OP201027   Rosie 2024-03-27     S1        4            20o27S1c4  D1
# 575  OP210323   Rosie 2024-06-07  S4_D2        5  2021_03_25_0S4_D2c5  D2
# 576  OP220217   Verji 2024-06-04  S2_D2        1         22218S2_D2c1  D2
# 577  OP230109   Verji 2024-02-28  S1_D2        2          2311S1_D2c2  D2
# 578  OP230314   Verji 2024-07-18     S2        8            23314S2c8  D1
# 579  OP220228   Verji 2024-05-24  S3_D2        7         22228S3_D2c7  D2
# 580  OP220602     NaN 2024-02-28     S1        5            22602S1c5  D1
# 581  OP220623   Verji 2024-01-07     S3        2            22623S3c2  D1
# 582  OP240411   Verji 2024-02-07     S2        6            24411S2c6  D1
# 583  OP230817   Verji 2024-05-08     S3        7            23817S3c7  D1
# 584  OP240417   Verji 2024-02-12     S1        2            24417S1c2  D1
# 585  OP220426   Verji 2024-01-20  S3_D2        3            22427S3c3  D2
# 586  OP240221   Verji 2024-06-20     S2        2            24221S2c2  D1
# 587  OP230426   Verji 2024-01-15     S2        8            23426S2c8  D1
# 588  OP240321   Verji 2024-04-21  S2_D2        4            24321S2c6  D2
# 589  OP220602     NaN 2024-06-02     S3        4            22602S3c4  D1
# 590  OP230314   Verji 2024-07-17     S2        4            23314S2c4  D1
# 591  OP240321   Verji 2024-04-11     S2        2            24321S2c2  D1
# 592  OP221024   Verji 2024-06-14     S2        7            22o24S2c7  D1
# 593  OP230808   Verji 2024-03-28     S1        2            23808S1c2  D1
# 594  OP210323   Rosie 2024-06-10  S5_D2        2  2021_03_25_0S5_D2c2  D2
# 595  OP210323   Rosie 2024-05-29     S5        2     2021_03_24_0S5c3  D1
# 596  OP220518   Verji 2024-07-07     S2        1            22519S2c1  D1
# 597  OP220127   Rosie 2024-07-18     S4        6            22128S4c6  D1
# 598  OP230808   Verji 2024-03-31  S2_D2        2            23808S2c8  D2
# 599  OP210323   Rosie 2024-05-03     S3        4     2021_03_24_0S3c4  D1
# 600  OP220308   Verji 2024-06-22     S3        3            22308S3c3  D1
# 601  OP230808   Verji 2024-04-06     S6        6            23808S6c6  D1
# 602  OP240411   Verji 2024-02-06     S1        6            24411S1c6  D1
# 603  OP220308   Verji 2024-06-22     S2        8            22308S2c8  D1
# 604  OP210615   Rosie 2024-03-09  S2_D2        4  2021_06_16_0S2_D2c4  D2
# 605  OP230420   Verji 2024-01-02     S2        2            23420S2c2  D1
# 606  OP210615   Rosie 2024-03-06     S2        2     2021_06_15_0S2c3  D1
# 607  OP220228   Verji 2024-05-22     S3        5            22228S3c5  D1
# 608  OP201029   Rosie 2024-03-16     S1        7            20o29S1c7  D1
# 609  OP230209   Verji 2024-04-22     S2        6            23209S2c6  D1
# 610  OP230523   Verji 2024-03-10     S2        8            23523S2c8  D1
# 611  OP220127   Rosie 2024-06-28     S1        6            22128S1c6  D1
# 612  OP220127   Rosie 2024-07-26  S3_D2        5         22129S3_D2c5  D2
# 613  OP211123   Rosie 2024-01-12  S2_D2        5         21n24S2_D2c5  D2
# 614  OP230817   Verji 2024-05-05     S2        5            23817S2c5  D1
# 615  OP220111   Rosie 2024-06-16  S6_D2        7         22112S6_D2c7  D2
# 616  OP230808   Verji 2024-04-05     S6        2            23808S6c2  D1
# 617  OP211209   Verji 2024-03-12     S1        8            21d10S1c8  D1
# 618  OP220426   Verji 2024-01-21     S4        6            22427S4c6  D1
# 619  OP240417   Verji 2024-02-14     S1        5            24417S1c5  D1
# 620  OP211123   Rosie 2024-04-05     S3        4     2021_11_24_0S3c4  D1
# 621  OP221027   Verji 2024-02-05     S3        4            22o27S3c4  D1
# ...
# 633                 8 mM     -60.418195       Virchow  temporal         12.0
# 634                15 mM     -68.706589       Virchow  temporal         10.0
# 635                15 mM     -70.734058       Virchow  temporal         10.0
# 636                15 mM     -62.886175     Bielefeld  temporal         60.0
# 637                15 mM     -57.848791     Bielefeld  temporal         27.0
# 638                 8 mM     -53.845886         Mitte  temporal         61.0
# 639                15 mM     -60.703855         Mitte  temporal         45.0
# 640                15 mM     -57.305179     Bielefeld  temporal         51.0
# 641                 8 mM     -61.804011     Bielefeld  temporal         42.0
# 642                 8 mM     -60.945311     Bielefeld  temporal         63.0
# 643                15 mM     -73.953792     Bielefeld  temporal         52.0
# 644                 8 mM     -61.676776       Virchow  temporal         12.0
# 645                 8 mM     -61.721657         Mitte  temporal         63.0
# 646                 8 mM     -61.267633         Mitte  temporal         47.0
# 647                 8 mM     -62.488351         Mitte   frontal         32.0
# 648                15 mM     -71.667057       Virchow  temporal         10.0
# 649                15 mM     -59.302153         Mitte  temporal         45.0
# 650                 8 mM     -62.295839         Mitte  temporal         61.0
# 651                 8 mM     -60.337102       Hamburg  temporal         14.0
# 652                15 mM     -68.241605       Virchow  temporal         10.0
# 653                 8 mM     -63.649731       Hamburg  temporal         29.0
# 654                 8 mM     -60.046000     Bielefeld  temporal         63.0
# 655                 8 mM     -59.182059     Bielefeld  temporal         30.0
# 656                15 mM     -58.481339     Bielefeld  temporal         33.0
# 657                 8 mM     -61.644374     Bielefeld  temporal         13.0
# 658                 8 mM     -62.120116         Mitte  temporal         63.0
#
#     days from prev
# 0           0 days
# 1           0 days
# 2           1 days
# 3           0 days
# 4           2 days
# 5           2 days
# 6           1 days
# 7           1 days
# 8           1 days
# 9           1 days
# 10          2 days
# 11          0 days
# 12          1 days
# 13          1 days
# 14          1 days
# 15          0 days
# 16          0 days
# 17          1 days
# 18          1 days
# 19          1 days
# 20          0 days
# 21          1 days
# 22          1 days
# 23          0 days
# 24          0 days
# 25          0 days
# 26          0 days
# 27          1 days
# 28          0 days
# 29          1 days
# 30          0 days
# 31          0 days
# 32          2 days
# 33          0 days
# 34          0 days
# 35          0 days
# 36          0 days
# 37          0 days
# 38          2 days
# 39          0 days
# 40          3 days
# 41          0 days
# 42          1 days
# 43          0 days
# 44          1 days
# 45          1 days
# 46          0 days
# 47          1 days
# 48          0 days
# 49          0 days
# 50          0 days
# 51          1 days
# 52          2 days
# 53          0 days
# 54          0 days
# 55          1 days
# 56          1 days
# 57             NaT
# 58          0 days
# 59          0 days
# 60          0 days
# 61          1 days
# 62          1 days
# 63          0 days
# 64          0 days
# 65          0 days
# 66          1 days
# 67          1 days
# 68          0 days
# 69          0 days
# 70          1 days
# 71          0 days
# 72          2 days
# 73          0 days
# 74          1 days
# 75          0 days
# 76             NaT
# 77          0 days
# 78          1 days
# 79          1 days
# 80          0 days
# 81          0 days
# 82          0 days
# 83          0 days
# 84          0 days
# 85          1 days
# 86          1 days
# 87          1 days
# 88          0 days
# 89          0 days
# 90          0 days
# 91          1 days
# 92          1 days
# 93          1 days
# 94          1 days
# 95          0 days
# 96          0 days
# 97          1 days
# 98          0 days
# 99          0 days
# 100         2 days
# 101         1 days
# 102         3 days
# 103         1 days
# 104         0 days
# 105         1 days
# 106         0 days
# 107         6 days
# 108         0 days
# 109         0 days
# 110         2 days
# 111         2 days
# 112         0 days
# 113         1 days
# 114         2 days
# 115         0 days
# 116         1 days
# 117         1 days
# 118         0 days
# 119         2 days
# 120         1 days
# 121         5 days
# 122         0 days
# 123         2 days
# 124         1 days
# 125         1 days
# 126         0 days
# 127         0 days
# 128         0 days
# 129         0 days
# 130         0 days
# 131         1 days
# 132         0 days
# 133         1 days
# 134         0 days
# 135         0 days
# 136            NaT
# 137         0 days
# 138         0 days
# 139         1 days
# 140         1 days
# 141         1 days
# 142            NaT
# 143         1 days
# 144         1 days
# 145         0 days
# 146         0 days
# 147         1 days
# 148         2 days
# 149         1 days
# 150         0 days
# 151         1 days
# 152         0 days
# 153         0 days
# 154         1 days
# 155         2 days
# 156         1 days
# 157         0 days
# 158         0 days
# 159         1 days
# 160         1 days
# 161         0 days
# 162         0 days
# 163         1 days
# 164         0 days
# 165         0 days
# 166         0 days
# 167         0 days
# 168         1 days
# 169         1 days
# 170         0 days
# 171         0 days
# 172         1 days
# 173         0 days
# 174         0 days
# 175         1 days
# 176         1 days
# 177         0 days
# 178         0 days
# 179         1 days
# 180         2 days
# 181         1 days
# 182         1 days
# 183         1 days
# 184         0 days
# 185         0 days
# 186         0 days
# 187         0 days
# 188         1 days
# 189         0 days
# 190         1 days
# 191         0 days
# 192         0 days
# 193         0 days
# 194         0 days
# 195         1 days
# 196         1 days
# 197         0 days
# 198         1 days
# 199         0 days
# 200         0 days
# 201         1 days
# 202         1 days
# 203         0 days
# 204         1 days
# 205            NaT
# 206         3 days
# 207         0 days
# 208         2 days
# 209         0 days
# 210         0 days
# 211         2 days
# 212         4 days
# 213         1 days
# 214         1 days
# 215         1 days
# 216         1 days
# 217         1 days
# 218         0 days
# 219         0 days
# 220         1 days
# 221         0 days
# 222         0 days
# 223         0 days
# 224         1 days
# 225         1 days
# 226         2 days
# 227         2 days
# 228         1 days
# 229         1 days
# 230         1 days
# 231         2 days
# 232         4 days
# 233         2 days
# 234         1 days
# 235         1 days
# 236         2 days
# 237         0 days
# 238         1 days
# 239         0 days
# 240         0 days
# 241         2 days
# 242         1 days
# 243         0 days
# 244         0 days
# 245         1 days
# 246         1 days
# 247         0 days
# 248         0 days
# 249         2 days
# 250         1 days
# 251            NaT
# 252         0 days
# 253         0 days
# 254         1 days
# 255         1 days
# 256         0 days
# 257         0 days
# 258         0 days
# 259         0 days
# 260         0 days
# 261            NaT
# 262         1 days
# 263         1 days
# 264         1 days
# 265         1 days
# 266         0 days
# 267         3 days
# 268         0 days
# 269         0 days
# 270         4 days
# 271         0 days
# 272         0 days
# 273         0 days
# 274         1 days
# 275         0 days
# 276         0 days
# 277         2 days
# 278         1 days
# 279            NaT
# 280            NaT
# 281         0 days
# 282         0 days
# 283         0 days
# 284         0 days
# 285         1 days
# 286         1 days
# 287         0 days
# 288         1 days
# 289         1 days
# 290         0 days
# 291         0 days
# 292         1 days
# 293         0 days
# 294         1 days
# 295         3 days
# 296         1 days
# 297         4 days
# 298         0 days
# 299         0 days
# 300         1 days
# 301         0 days
# 302         0 days
# 303         0 days
# 304         0 days
# 305         0 days
# 306         0 days
# 307         0 days
# 308         1 days
# 309         1 days
# 310         0 days
# 311         1 days
# 312         1 days
# 313         0 days
# 314         2 days
# 315         0 days
# 316         1 days
# 317            NaT
# 318         2 days
# 319         1 days
# 320         2 days
# 321         0 days
# 322         2 days
# 323         1 days
# 324         2 days
# 325         0 days
# 326         0 days
# 327         2 days
# 328         0 days
# 329         1 days
# 330         0 days
# 331         0 days
# 332         1 days
# 333         2 days
# 334         0 days
# 335         1 days
# 336         1 days
# 337         0 days
# 338         0 days
# 339         0 days
# 340         5 days
# 341         0 days
# 342         0 days
# 343         0 days
# 344         1 days
# 345         1 days
# 346         2 days
# 347         1 days
# 348         0 days
# 349         1 days
# 350         1 days
# 351         0 days
# 352         0 days
# 353         0 days
# 354         1 days
# 355         0 days
# 356         2 days
# 357         2 days
# 358         0 days
# 359         0 days
# 360         0 days
# 361         0 days
# 362         1 days
# 363         0 days
# 364         0 days
# 365         1 days
# 366         0 days
# 367         0 days
# 368            NaT
# 369         1 days
# 370         0 days
# 371         1 days
# 372         0 days
# 373         1 days
# 374         1 days
# 375         1 days
# 376         1 days
# 377         1 days
# 378         0 days
# 379         0 days
# 380         1 days
# 381         1 days
# 382         1 days
# 383         1 days
# 384         0 days
# 385            NaT
# 386         6 days
# 387         1 days
# 388         0 days
# 389         1 days
# 390         0 days
# 391         2 days
# 392         0 days
# 393         0 days
# 394         0 days
# 395         0 days
# 396         0 days
# 397         1 days
# 398         0 days
# 399         0 days
# 400         1 days
# 401         1 days
# 402         1 days
# 403         0 days
# 404         0 days
# 405         0 days
# 406         1 days
# 407            NaT
# 408         1 days
# 409         0 days
# 410         1 days
# 411         0 days
# 412         0 days
# 413         0 days
# 414         0 days
# 415         0 days
# 416         1 days
# 417         0 days
# 418         0 days
# 419         0 days
# 420         1 days
# 421         0 days
# 422         1 days
# 423         1 days
# 424         1 days
# 425         0 days
# 426         0 days
# 427         1 days
# 428            NaT
# 429         0 days
# 430         0 days
# 431         1 days
# 432         0 days
# 433         2 days
# 434         1 days
# 435         0 days
# 436         1 days
# 437         0 days
# 438         1 days
# 439         0 days
# 440         1 days
# 441         1 days
# 442         0 days
# 443         1 days
# 444         1 days
# 445         1 days
# 446         1 days
# 447         0 days
# 448         0 days
# 449         0 days
# 450         1 days
# 451         0 days
# 452         0 days
# 453         0 days
# 454         0 days
# 455         3 days
# 456         1 days
# 457         1 days
# 458         3 days
# 459         2 days
# 460         0 days
# 461         0 days
# 462         0 days
# 463         0 days
# 464         0 days
# 465         0 days
# 466         1 days
# 467         0 days
# 468         1 days
# 469         1 days
# 470         0 days
# 471         1 days
# 472         1 days
# 473         1 days
# 474            NaT
# 475         0 days
# 476         1 days
# 477         0 days
# 478         0 days
# 479         3 days
# 480         1 days
# 481         0 days
# 482         0 days
# 483         0 days
# 484         2 days
# 485         1 days
# 486         2 days
# 487         0 days
# 488         0 days
# 489         0 days
# 490         1 days
# 491         1 days
# 492         1 days
# 493         0 days
# 494         0 days
# 495         0 days
# 496         2 days
# 497            NaT
# 498         0 days
# 499         0 days
# 500         0 days
# 501         2 days
# 502         0 days
# 503         1 days
# 504         1 days
# 505         1 days
# 506         1 days
# 507         1 days
# 508         1 days
# 509         0 days
# 510         2 days
# 511            NaT
# 512         1 days
# 513         1 days
# 514         1 days
# 515         0 days
# 516         1 days
# 517         1 days
# 518         0 days
# 519         0 days
# 520         1 days
# 521         0 days
# 522         1 days
# 523         0 days
# 524         1 days
# 525         0 days
# 526         2 days
# 527         0 days
# 528         0 days
# 529         0 days
# 530         1 days
# 531         1 days
# 532         0 days
# 533         0 days
# 534         0 days
# 535         1 days
# 536         1 days
# 537         1 days
# 538         1 days
# 539         0 days
# 540         0 days
# 541         1 days
# 542         0 days
# 543         1 days
# 544         2 days
# 545         0 days
# 546         0 days
# 547         0 days
# 548         0 days
# 549         0 days
# 550         0 days
# 551         0 days
# 552         1 days
# 553         1 days
# 554         0 days
# 555            NaT
# 556         0 days
# 557         0 days
# 558         1 days
# 559         0 days
# 560         1 days
# 561         0 days
# 562         0 days
# 563            NaT
# 564         0 days
# 565         0 days
# 566         1 days
# 567         0 days
# 568         2 days
# 569         0 days
# 570         0 days
# 571         0 days
# 572         1 days
# 573         0 days
# 574         0 days
# 575         2 days
# 576         1 days
# 577         0 days
# 578         1 days
# 579         0 days
# 580            NaT
# 581         0 days
# 582         1 days
# 583         1 days
# 584         0 days
# 585         0 days
# 586         0 days
# 587         1 days
# 588         1 days
# 589            NaT
# 590         0 days
# 591         0 days
# 592         0 days
# 593         0 days
# 594         0 days
# 595         5 days
# 596         0 days
# 597         2 days
# 598         0 days
# 599         4 days
# 600         0 days
# 601         0 days
# 602         0 days
# 603         1 days
# 604         1 days
# 605         0 days
# 606         0 days
# 607         1 days
# 608         1 days
# 609         1 days
# 610         0 days
# 611         1 days
# 612         0 days
# 613         1 days
# 614         1 days
# 615         1 days
# 616         1 days
# 617         0 days
# 618         1 days
# 619         1 days
# 620         1 days
# 621         0 days
# 622         0 days
# 623         1 days
# 624         3 days
# 625         1 days
# 626         1 days
# 627         0 days
# 628         0 days
# 629         0 days
# 630         1 days
# 631         1 days
# 632         1 days
# 633         0 days
# 634         1 days
# 635         2 days
# 636         0 days
# 637         0 days
# 638         1 days
# 639         0 days
# 640         1 days
# 641         0 days
# 642         0 days
# 643         0 days
# 644         0 days
# 645         1 days
# 646         2 days
# 647         0 days
# 648         1 days
# 649         2 days
# 650         0 days
# 651         1 days
# 652         1 days
# 653         0 days
# 654         1 days
# 655         0 days
# 656         1 days
# 657         1 days
# 658         0 days

# %%
df.sort_values(['patcher', 'date'])[['patcher', 'date', 'days from prev']].head() # this is just to view your data more intuitively
# Out:
#     patcher       date days from prev
# 251   Rosie 2024-01-01            NaT
# 102   Rosie 2024-01-04         3 days
# 355   Rosie 2024-01-04         0 days
# 47    Rosie 2024-01-05         1 days
# 477   Rosie 2024-01-05         0 days

# %%
df.groupby('patcher')['days from prev'].mean() # this is to calculate those means
# Out:
# patcher
# Rosie   1 days 05:45:15.789473684
# Verji   0 days 10:53:42.269807280
# Name: days from prev, dtype: timedelta64[ns]
